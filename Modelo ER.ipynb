# %%
import pandas as pd

# %%
df_carro_spec = pd.read_csv("./data/car_noise_specification_datasets.csv", sep= "\t")

# %%
df_carro_spec.head(1)
# Out:
#    Unnamed: 0   brand model           spec    year  dB_at_idle  dB_at_50kmh  \
# 0           0  Abarth   500  1.4 16v T-Jet  2008.0        47.3         58.2
#
#    dB_at_80kmh  dB_at_100kmh  dB_at_120kmh  ...  model_height_in_cqa  \
# 0         67.0          70.2          72.9  ...                  NaN
#
#    model_wheelbase_in_cqa  model_mpg_hwy_cqa model_mpg_city_cqa  \
# 0                     NaN                NaN                NaN
#
#   model_mpg_mixed_cqa model_fuel_cap_g_cqa  make_display_cqa make_country_cqa  \
# 0                 NaN                  NaN               NaN              NaN
#
#   ExtColors_cqa  IntColors_cqa
# 0           NaN            NaN
#
# [1 rows x 72 columns]

# %%
df_carro_spec[df_carro_spec['brand'] == "Acura"]
# Out:
#     Unnamed: 0  brand model        spec    year  dB_at_idle  dB_at_50kmh  \
# 2            2  Acura   MDX      3.5 V6  2013.0        41.7         51.7
# 3            3  Acura   RDX      3.5 V6  2012.0        43.0         54.4
# 4            4  Acura    RL      3.7 V6  2009.0        43.6         55.5
# 5            5  Acura   RLX      3.5 V6  2013.0        39.5         49.7
# 6            6  Acura   RLX      3.5 V6  2016.0        42.2         51.1
# 7            7  Acura    TL      3.5 V6  2009.0        40.2         54.5
# 8            8  Acura    TL      3.7 V6  2010.0        39.9         48.4
# 9            9  Acura   TSX         2.4  2009.0        42.2         54.0
# 10          10  Acura   TSX          V6  2010.0        42.4         54.3
# 11          11  Acura   TSX  Stationcar  2011.0        48.8         56.7
#
#     dB_at_80kmh  dB_at_100kmh  dB_at_120kmh  ...  model_height_in_cqa  \
# 2          57.9          61.2          64.0  ...                 68.2
# ...

# %%
df_electric = pd.read_csv("./data/ElectricCarData_Clean.csv")

# %%
df_electric.head()
# Out:
#    Brand        Model                             AccelSec   TopSpeed_KmH   \
# 0  Tesla        Model 3 Long Range Dual Motor           4.6            233
# 1  Volkswagen   ID.3 Pure                              10.0            160
# 2  Polestar     2                                       4.7            210
# 3  BMW          iX3                                     6.8            180
# 4  Honda        e                                       9.5            145
#
#    Range_Km   Efficiency_WhKm   FastCharge_KmH   RapidCharge   PowerTrain   \
# 0        450               161  940              Yes           AWD
# 1        270               167  250              Yes           RWD
# 2        400               181  620              Yes           AWD
# 3        360               206  560              Yes           RWD
# 4        170               168  190              Yes           RWD
#
#    PlugType         BodyStyle   Segment   Seats   PriceEuro
# ...

# %%
df_electric[df_electric['Brand      '] == 'Volvo']
# Out:
# Empty DataFrame
# Columns: [Brand      , Model                           , AccelSec , TopSpeed_KmH , Range_Km , Efficiency_WhKm , FastCharge_KmH , RapidCharge , PowerTrain , PlugType       , BodyStyle , Segment , Seats , PriceEuro]
# Index: []

# %%
df_consumo = pd.read_csv("./data/MY2023 Fuel Consumption Ratings.csv")

# %%
df_consumo.tail()
# Out:
#      Model Year   Make            \
# 818         2023  Volvo
# 819         2023  Volvo
# 820         2023  Volvo
# 821         2023  Volvo
# 822         2023  Volvo
#
#      Model                                            \
# 818  XC40 B5 AWD
# 819  XC60 B5 AWD
# 820  XC60 B6 AWD
# 821  XC90 B5 AWD
# 822  XC90 B6 AWD
#
#      Vehicle Class             Engine Size (L)   Cylinders   Transmission   \
# 818  SUV: Small                             2.0           4  AS8
# 819  SUV: Small                             2.0           4  AS8
# 820  SUV: Small                             2.0           4  AS8
# 821  SUV: Standard                          2.0           4  AS8
# 822  SUV: Standard                          2.0           4  AS8
#
#      Fuel Type   Fuel Consumption City (L/100 km)   Fuel Consumption Hwy   \
# 818  Z                                        10.2                    7.9
# 819  Z                                        10.3                    8.2
# ...

# %%
df_consumo.iloc[:, 200:]
# Out:
#      .185  .186  .187  .188  .189  .190  .191  .192  .193  .194  ...  .199  \
# 0                                                                ...
# 1                                                                ...
# 2                                                                ...
# 3                                                                ...
# 4                                                                ...
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 818                                                              ...
# 819                                                              ...
# 820                                                              ...
# 821                                                              ...
# 822                                                              ...
#
#      .200  .201  .202  .203  .204  .205  .206  .207 Unnamed: 223
# ...

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %%
import re
def funcQuitaEspacios(cadena):
    if isinstance(cadena, str):

    # Utiliza la función re.sub para reemplazar múltiples espacios por uno solo
        cadena_sin_espacios_extra = re.sub(r'\s+', ' ', cadena).strip().lower()
        return cadena_sin_espacios_extra
    else:
        pass

# %%
marcas_1, marcas_2, marcas_3 = df_electric['Brand      '].apply(lambda x: funcQuitaEspacios(x)), df_carro_spec['brand'].apply(lambda x: funcQuitaEspacios(x)), df_consumo['Make          '].apply(lambda x: funcQuitaEspacios(x))

# %%
list_models = []
for model in marcas_1:
    if model not in list_models:
        list_models.append(model)
    else:
        continue

len(list_models)
# list_models = []
for model in marcas_2:
    if model not in list_models:
        list_models.append(model)
    else:
        continue

len(list_models)
# list_models = []
for model in marcas_3:
    if model not in list_models:
        list_models.append(model)
    else:
        continue

len(list_models)
# Out:
# 33

# %%
index_None = list_models.index(None)
del list_models[index_None]

# %%
list_models.sort()

# %%
list_models
# Out:
# ['abarth',
#  'acura',
#  'aiways',
#  'alfa romeo',
#  'alpina',
#  'aston martin',
#  'audi',
#  'bentley',
#  'bmw',
#  'bugatti',
#  'buick',
#  'byton',
#  'cadillac',
#  'chevrolet',
#  'chrysler',
#  'citroen',
#  'cupra',
#  'dacia',
#  'daihatsu',
#  'dodge',
#  'ds',
#  'fiat',
#  'ford',
#  'genesis',
#  'gmc',
#  'honda',
#  'hummer',
#  'hyundai',
#  'infiniti',
#  'infinity',
#  'jaguar',
#  'jeep',
#  'kia',
#  'lamborghini',
#  'lancia',
#  'land rover',
#  'lexus',
#  'lightyear',
#  'lincoln',
#  'lotus',
#  'lucid',
#  'maserati',
#  'mazda',
#  'mclaren',
#  'mercedes',
#  'mercedes-benz',
#  'mercury',
#  'mg',
#  'mini',
#  'mitsubihi',
#  'mitsubishi',
#  'nissan',
#  'opel',
#  'peugeot',
#  'polestar',
#  'pontiac',
#  'porsche',
#  'ram',
#  'range rover',
#  'renault',
#  'rolls royce',
#  'rolls-royce',
#  'saab',
#  'saturn',
#  'scion',
#  'seat',
#  'skoda',
#  'smart',
#  'sono',
#  'srt',
#  'ssangyong',
#  'subaru',
#  'suzuki',
#  'tesla',
# ...

# %%
brand_models = {}
for i, brand in enumerate(list_models):
    brand_models[f"{i}"] = brand

brand_models
# Out:
# {'0': 'abarth',
#  '1': 'acura',
#  '2': 'aiways',
#  '3': 'alfa romeo',
#  '4': 'alpina',
#  '5': 'aston martin',
#  '6': 'audi',
#  '7': 'bentley',
#  '8': 'bmw',
#  '9': 'bugatti',
#  '10': 'buick',
#  '11': 'byton',
#  '12': 'cadillac',
#  '13': 'chevrolet',
#  '14': 'chrysler',
#  '15': 'citroen',
#  '16': 'cupra',
#  '17': 'dacia',
#  '18': 'daihatsu',
#  '19': 'dodge',
#  '20': 'ds',
#  '21': 'fiat',
#  '22': 'ford',
#  '23': 'genesis',
#  '24': 'gmc',
#  '25': 'honda',
#  '26': 'hummer',
#  '27': 'hyundai',
#  '28': 'infiniti',
#  '29': 'infinity',
#  '30': 'jaguar',
#  '31': 'jeep',
#  '32': 'kia',
#  '33': 'lamborghini',
#  '34': 'lancia',
#  '35': 'land rover',
#  '36': 'lexus',
#  '37': 'lightyear',
#  '38': 'lincoln',
#  '39': 'lotus',
#  '40': 'lucid',
#  '41': 'maserati',
#  '42': 'mazda',
#  '43': 'mclaren',
#  '44': 'mercedes',
#  '45': 'mercedes-benz',
#  '46': 'mercury',
#  '47': 'mg',
#  '48': 'mini',
#  '49': 'mitsubihi',
#  '50': 'mitsubishi',
# ...

# %%
brand_table = pd.DataFrame(brand_models, index=range(1)).T.reset_index(names= "Brand_ID").rename(columns= {0: "Brand_Name"})

# %%
brand_table.to_csv("./modelo ER/brand_table.csv", index= False)

# %%
df_consumo.head(1)
# Out:
#    Model Year   Make            \
# 0         2023  Acura
#
#    Model                                            Vehicle Class             \
# 0  Integra                                          Full-size
#
#    Engine Size (L)   Cylinders   Transmission   Fuel Type   \
# 0               1.5           4  AV7            Z
#
#    Fuel Consumption City (L/100 km)   Fuel Consumption Hwy   ...   .199  \
# 0                                7.9                    6.3  ...
#
#     .200   .201   .202   .203  .204  .205  .206  .207 Unnamed: 223
# 0                                                              NaN
#
# [1 rows x 224 columns]

# %%
df_electric.head(1)
# Out:
#    Brand        Model                             AccelSec   TopSpeed_KmH   \
# 0  Tesla        Model 3 Long Range Dual Motor           4.6            233
#
#    Range_Km   Efficiency_WhKm   FastCharge_KmH   RapidCharge   PowerTrain   \
# 0        450               161  940              Yes           AWD
#
#    PlugType         BodyStyle   Segment   Seats   PriceEuro
# 0  Type 2 CCS       Sedan       D              5      55480

# %%
df_carro_spec.head(1)
# Out:
#    Unnamed: 0   brand model           spec    year  dB_at_idle  dB_at_50kmh  \
# 0           0  Abarth   500  1.4 16v T-Jet  2008.0        47.3         58.2
#
#    dB_at_80kmh  dB_at_100kmh  dB_at_120kmh  ...  model_height_in_cqa  \
# 0         67.0          70.2          72.9  ...                  NaN
#
#    model_wheelbase_in_cqa  model_mpg_hwy_cqa model_mpg_city_cqa  \
# 0                     NaN                NaN                NaN
#
#   model_mpg_mixed_cqa model_fuel_cap_g_cqa  make_display_cqa make_country_cqa  \
# 0                 NaN                  NaN               NaN              NaN
#
#   ExtColors_cqa  IntColors_cqa
# 0           NaN            NaN
#
# [1 rows x 72 columns]

# %%
models_consumo = df_consumo[['Model Year ', "Make          ", "Model                                          "]]

# %%
models_consumo
# Out:
#      Model Year   Make            \
# 0           2023  Acura
# 1           2023  Acura
# 2           2023  Acura
# 3           2023  Acura
# 4           2023  Acura
# ..           ...             ...
# 818         2023  Volvo
# 819         2023  Volvo
# 820         2023  Volvo
# 821         2023  Volvo
# 822         2023  Volvo
#
#      Model
# 0    Integra
# 1    Integra A-SPEC
# 2    Integra A-SPEC
# 3    MDX SH-AWD
# 4    MDX SH-AWD Type S
# ..                                               ...
# 818  XC40 B5 AWD
# 819  XC60 B5 AWD
# 820  XC60 B6 AWD
# 821  XC90 B5 AWD
# 822  XC90 B6 AWD
#
# [823 rows x 3 columns]

# %%
for i, brand in brand_table.values:
    models_consumo['Make          '] = models_consumo['Make          '].str.replace(f"{brand}", f"{i}", case=False)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_384\3068659259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   models_consumo['Make          '] = models_consumo['Make          '].str.replace(f"{brand}", f"{i}", case=False)

# %%
models_consumo = models_consumo.reset_index(names= "model&year_ID")
models_consumo.head()
# Out:
#    model&year_ID  Model Year  Make            \
# 0              0         2023     1
# 1              1         2023     1
# 2              2         2023     1
# 3              3         2023     1
# 4              4         2023     1
#
#    Model
# 0  Integra
# 1  Integra A-SPEC
# 2  Integra A-SPEC
# 3  MDX SH-AWD
# 4  MDX SH-AWD Type S

# %%
models_consumo.columns = ["Model_ID", "Year", "Brand_ID", "Model_Name"]

# %%
models_consumo
# Out:
#      Model_ID  Year     Brand_ID  \
# 0           0  2023   1
# 1           1  2023   1
# 2           2  2023   1
# 3           3  2023   1
# 4           4  2023   1
# ..        ...   ...          ...
# 818       818  2023  76
# 819       819  2023  76
# 820       820  2023  76
# 821       821  2023  76
# 822       822  2023  76
#
#                                           Model_Name
# 0    Integra
# 1    Integra A-SPEC
# 2    Integra A-SPEC
# 3    MDX SH-AWD
# 4    MDX SH-AWD Type S
# ..                                               ...
# 818  XC40 B5 AWD
# 819  XC60 B5 AWD
# 820  XC60 B6 AWD
# 821  XC90 B5 AWD
# 822  XC90 B6 AWD
#
# [823 rows x 4 columns]

# %%
df_consumo['Model_ID'] = models_consumo['Model_ID']

# %%
df_consumo.head(1)
# Out:
#    Model Year   Make            \
# 0         2023  Acura
#
#    Model                                            Vehicle Class             \
# 0  Integra                                          Full-size
#
#    Engine Size (L)   Cylinders   Transmission   Fuel Type   \
# 0               1.5           4  AV7            Z
#
#    Fuel Consumption City (L/100 km)   Fuel Consumption Hwy   ...   .200  \
# 0                                7.9                    6.3  ...
#
#     .201   .202   .203   .204  .205  .206  .207 Unnamed: 223 Model_ID
# 0                                                        NaN        0
#
# [1 rows x 225 columns]

# %%
table_consumo = df_consumo.iloc[:, 3:16]

# %%
table_consumo['Model_ID'] = models_consumo['Model_ID']

# %%
table_consumo.head()
# Out:
#    Vehicle Class             Engine Size (L)   Cylinders   Transmission   \
# 0  Full-size                              1.5           4  AV7
# 1  Full-size                              1.5           4  AV7
# 2  Full-size                              1.5           4  M6
# 3  SUV: Small                             3.5           6  AS10
# 4  SUV: Standard                          3.0           6  AS10
#
#    Fuel Type   Fuel Consumption City (L/100 km)   Fuel Consumption Hwy   \
# 0  Z                                         7.9                    6.3
# 1  Z                                         8.1                    6.5
# 2  Z                                         8.9                    6.5
# 3  Z                                        12.6                    9.4
# 4  Z                                        13.8                   11.2
#
#    Fuel Consumption Comb (L/100 km)   Fuel Consumption Comb (mpg)   \
# 0                                7.2                            39
# ...

# %%
table_consumo.to_csv("./modelo ER/My2023 Fuel Consumption Rating.csv", index= False)

# %%
models_consumo.head()
# Out:
#    Model_ID  Year    Brand_ID                                       Model_Name
# 0         0  2023  1           Integra
# 1         1  2023  1           Integra A-SPEC
# 2         2  2023  1           Integra A-SPEC
# 3         3  2023  1           MDX SH-AWD
# 4         4  2023  1           MDX SH-AWD Type S

# %%
models_consumo.to_csv("./modelo ER/modelos_Consumption.csv", index= False)

# %%
df_electric.head()
# Out:
#    Brand        Model                             AccelSec   TopSpeed_KmH   \
# 0  Tesla        Model 3 Long Range Dual Motor           4.6            233
# 1  Volkswagen   ID.3 Pure                              10.0            160
# 2  Polestar     2                                       4.7            210
# 3  BMW          iX3                                     6.8            180
# 4  Honda        e                                       9.5            145
#
#    Range_Km   Efficiency_WhKm   FastCharge_KmH   RapidCharge   PowerTrain   \
# 0        450               161  940              Yes           AWD
# 1        270               167  250              Yes           RWD
# 2        400               181  620              Yes           AWD
# 3        360               206  560              Yes           RWD
# 4        170               168  190              Yes           RWD
#
#    PlugType         BodyStyle   Segment   Seats   PriceEuro
# ...

# %%
models_electric = df_electric.iloc[:, :2]

# %%
for id, brand in brand_table.values:
    models_electric['Brand      '] = models_electric['Brand      '].str.replace(f"{brand}", f"{id}", case= False)

# %%
models_electric.reset_index(names= "Model_ID", inplace= True)

# %%
models_electric.columns = ["Model_ID", "Brand_ID", 'Model_Name']

# %%
models_electric
# Out:
#      Model_ID   Brand_ID                        Model_Name
# 0           0   73        Model 3 Long Range Dual Motor
# 1           1        75   ID.3 Pure
# 2           2      54     2
# 3           3  8          iX3
# 4           4   25        e
# ..        ...        ...                               ...
# 98         98    51       Ariya 63kWh
# 99         99   6         e-tron S Sportback 55 quattro
# 100       100    51       Ariya e-4ORCE 63kWh
# 101       101    51       Ariya e-4ORCE 87kWh Performance
# 102       102   11        M-Byte 95 kWh 2WD
#
# [103 rows x 3 columns]

# %%
models_electric.to_csv("./modelo ER/modelos_ElectricCarData.csv", index= False)

# %%
table_electric = df_electric.iloc[:, 2:]

# %%
table_electric["Model_ID"] = models_electric['Model_ID']

# %%
table_electric.head()
# Out:
#    AccelSec   TopSpeed_KmH   Range_Km   Efficiency_WhKm   FastCharge_KmH   \
# 0        4.6            233        450               161  940
# 1       10.0            160        270               167  250
# 2        4.7            210        400               181  620
# 3        6.8            180        360               206  560
# 4        9.5            145        170               168  190
#
#    RapidCharge   PowerTrain   PlugType         BodyStyle   Segment   Seats   \
# 0  Yes           AWD          Type 2 CCS       Sedan       D              5
# 1  Yes           RWD          Type 2 CCS       Hatchback   C              5
# 2  Yes           AWD          Type 2 CCS       Liftback    D              5
# 3  Yes           RWD          Type 2 CCS       SUV         D              5
# 4  Yes           RWD          Type 2 CCS       Hatchback   B              4
#
#    PriceEuro  Model_ID
# 0      55480         0
# 1      30000         1
# 2      56440         2
# 3      68040         3
# ...

# %%
table_electric.to_csv("./modelo ER/ElectricCarData.csv", index=False)

# %%
df_carro_spec.head()
# Out:
#    Unnamed: 0   brand model           spec    year  dB_at_idle  dB_at_50kmh  \
# 0           0  Abarth   500  1.4 16v T-Jet  2008.0        47.3         58.2
# 1           1  Abarth   595   Competizione  2017.0        49.9         65.7
# 2           2   Acura   MDX         3.5 V6  2013.0        41.7         51.7
# 3           3   Acura   RDX         3.5 V6  2012.0        43.0         54.4
# 4           4   Acura    RL         3.7 V6  2009.0        43.6         55.5
#
#    dB_at_80kmh  dB_at_100kmh  dB_at_120kmh  ...  model_height_in_cqa  \
# 0         67.0          70.2          72.9  ...                  NaN
# 1         69.0          72.3          73.1  ...                  NaN
# 2         57.9          61.2          64.0  ...                 68.2
# 3         61.5          65.5          67.7  ...                 65.1
# 4         63.0          66.9          70.2  ...                 57.5
#
#    model_wheelbase_in_cqa  model_mpg_hwy_cqa model_mpg_city_cqa  \
# ...

# %%
models_spec = df_carro_spec.iloc[:, [1, 2, 4]]

# %%
models_spec
# Out:
#        brand model    year
# 0     Abarth   500  2008.0
# 1     Abarth   595  2017.0
# 2      Acura   MDX  2013.0
# 3      Acura   RDX  2012.0
# 4      Acura    RL  2009.0
# ...      ...   ...     ...
# 1890   Volvo  XC90  2017.0
# 1891   Volvo  XC90  2017.0
# 1892   Volvo  XC90  2018.0
# 1893   Volvo  XC90  2018.0
# 1894     NaN   NaN     NaN
#
# [1895 rows x 3 columns]

# %%
for id, brand in brand_table.values:
    models_spec['brand'] = models_spec['brand'].str.replace(f"{brand}", f"{id}", case=False)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_384\250555971.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   models_spec['brand'] = models_spec['brand'].str.replace(f"{brand}", f"{id}", case=False)

# %%
models_spec.columns = ["Brand_ID", "Model_Name", "Year"]

# %%
models_spec.reset_index(names= "Model_ID", inplace= True)

# %%
models_spec.to_csv("./modelo ER/modelos_car_specification.csv", index=False)

# %%
df_carro_spec["Model_ID"] = models_spec['Model_ID']

# %%
df_carro_spec.columns
# Out:
# Index(['Unnamed: 0', 'brand', 'model', 'spec', 'year', 'dB_at_idle',
#        'dB_at_50kmh', 'dB_at_80kmh', 'dB_at_100kmh', 'dB_at_120kmh',
#        'dB_at_140kmh', 'model_id', 'model_id_cqa', 'model_make_id_cqa',
#        'model_name_cqa', 'model_trim_cqa', 'model_year_cqa', 'model_body_cqa',
#        'model_engine_position_cqa', 'model_engine_cc_cqa',
#        'model_engine_cyl_cqa', 'model_engine_type_cqa',
#        'model_engine_valves_per_cyl_cqa', 'model_engine_power_ps_cqa',
#        'model_engine_power_rpm_cqa', 'model_engine_torque_nm_cqa',
#        'model_engine_torque_rpm_cqa', 'model_engine_bore_mm_cqa',
#        'model_engine_stroke_mm_cqa', 'model_engine_compression_cqa',
#        'model_engine_fuel_cqa', 'model_top_speed_kph_cqa',
#        'model_0_to_100_kph_cqa', 'model_drive_cqa',
#        'model_transmission_type_cqa', 'model_seats_cqa', 'model_doors_cqa',
#        'model_weight_kg_cqa', 'model_length_mm_cqa', 'model_width_mm_cqa',
# ...

# %%
df_carro_spec.drop(columns= ['Unnamed: 0', 'brand', 'model', 'year'], inplace= True)

# %%
df_carro_spec.to_csv("./modelo ER/car_noise_specification.csv", index=False)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_taxis = pd.read_csv("./data/taxi_2023-01.csv")

# %%
df_taxis.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df_zones = pd.read_csv("./data/taxi+_zone_lookup.csv")

# %%
df_zones
# Out:
#      LocationID   Borough         \
# 0              1  EWR
# 1              2  Queens
# 2              3  Bronx
# 3              4  Manhattan
# 4              5  Staten Island
# ..           ...             ...
# 260          261  Manhattan
# 261          262  Manhattan
# 262          263  Manhattan
# 263          264  Unknown
# 264          265  Unknown
#
#      Zone                                           service_zone
# 0    Newark Airport                                          EWR
# 1    Jamaica Bay                                       Boro Zone
# 2    Allerton/Pelham Gardens                           Boro Zone
# 3    Alphabet City                                   Yellow Zone
# 4    Arden Heights                                     Boro Zone
# ..                                              ...          ...
# 260  World Trade Center                              Yellow Zone
# 261  Yorkville East                                  Yellow Zone
# ...

# %%
df_aire = pd.read_csv("./data/Air_Quality_20231023.csv")
df_aire.head()
# Out:
#    Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0     216498           386            Ozone (O3)    Mean          ppb
# 1     216499           386            Ozone (O3)    Mean          ppb
# 2     219969           386            Ozone (O3)    Mean          ppb
# 3     219970           386            Ozone (O3)    Mean          ppb
# 4     164876           383  Sulfur Dioxide (SO2)    Mean          ppb
#
#   Geo Type Name  Geo Join ID                    Geo Place Name  \
# 0            CD          313               Coney Island (CD13)
# 1            CD          313               Coney Island (CD13)
# 2       Borough            1                             Bronx
# 3       Borough            1                             Bronx
# 4            CD          211  Morris Park and Bronxdale (CD11)
#
#       Time Period  Start_Date  Data Value  Message
# 0     Summer 2013  06/01/2013       34.64      NaN
# 1     Summer 2014  06/01/2014       33.22      NaN
# ...

# %%
table_locations_aire = df_aire[['Geo Place Name', 'Geo Join ID']]

# %%
table_locations_aire.drop_duplicates(inplace=True)

# %%
table_locations_aire['Geo Place Name']
# Out:
# 0                        Coney Island (CD13)
# 2                                      Bronx
# 4           Morris Park and Bronxdale (CD11)
# 5       Williamsbridge and Baychester (CD12)
# 6                                   Brooklyn
#                         ...
# 3629            Union Square-Lower Manhattan
# 3630       Bayside Little Neck-Fresh Meadows
# 3631                             Northern SI
# 3632                             Southern SI
# 3633                             South Bronx
# Name: Geo Place Name, Length: 114, dtype: object

# %%
import numpy as np
# table_locations_aire['Borough_ID'] = np.arange(0, len(table_locations_aire))

# %%
table_locations_aire
# Out:
#                             Geo Place Name  Geo Join ID
# 0                      Coney Island (CD13)          313
# 2                                    Bronx            1
# 4         Morris Park and Bronxdale (CD11)          211
# 5     Williamsbridge and Baychester (CD12)          212
# 6                                 Brooklyn            2
# ...                                    ...          ...
# 3629          Union Square-Lower Manhattan       309310
# 3630     Bayside Little Neck-Fresh Meadows       404406
# 3631                           Northern SI       501502
# 3632                           Southern SI       503504
# 3633                           South Bronx    105106107
#
# [114 rows x 2 columns]

# %%
diccionario_suburbios = {
    1: {"Borough": "Brooklyn",
         "District": ["Brooklyn",
            "Coney Island",
            "Greenpoint",
            "Fort Greene",
            "Bedford Stuyvesant",
            "Bushwick",
            "Esat New York",
            "Park Slope",
            "Sunset Park",
            "Crown Heights",
            "Bensonhurst",
            "Williamsburg"
        ]
    }, 
    2: {"Borough": "Bronx",
        "District": ["Bronx",
            "Morris Park",
            "Williamsbridge",
            "Belmont",
            "Kingsbridge",
            "Northeast Bronx",
            "Fordham - Bronx Pk",
            "Pelham",
            "Crotona",
            "High Bridge",
            "Hunts Point",
            "South Bronk",
            "Bronx"
        ]
    },
    3: {"Borough": "Queens",
        "District": ["Queens",
            "Long Island City",
            "Flushing",
            "Bayside",
            "Ridgewood",
            "Fresh Meadows",
            "Southwest Queens",
            "Jamaica",
            "Southeast Queens",
            "Rockaways"
        ]
    },
    4: { "Borough": "Staten Island",
        "District": ["Staten Island",
            "Port Richmond",
            "Stapleton",
            "Willowbrook",
            "South Beach",
            "Northern SI",
            "Southern SI"
        ]
    },
    5: { "Borough": "Manhattan",
        "District": ["Manhattan",
            "Financial District",
            "Greenwich Village",
            "Lower East Side",
            "Clinton and Chelsea",
            "Midtown",
            "Stuyvesant Town", 
            "Upper West Side",
            "Upper East Side",
            "Morningside Heights",
            "Central Harlem",
            "East Harlem",
            "Washington Heights",
            "Chelsea",
            "Union Square",
            "New York City"
        ]
    }
}

# %%
df_district = pd.DataFrame(diccionario_suburbios).T

# %%
df_district["Borough_ID"] = np
# Out:
#          Borough                                           District
# 1       Brooklyn  [Brooklyn, Coney Island, Greenpoint, Fort Gree...
# 2          Bronx  [Bronx, Morris Park, Williamsbridge, Belmont, ...
# 3         Queens  [Queens, Long Island City, Flushing, Bayside, ...
# 4  Staten Island  [Staten Island, Port Richmond, Stapleton, Will...
# 5      Manhattan  [Manhattan, Financial District, Greenwich Vill...

# %%
table_locations_aire['Borough'] = ["" for x in range(0, len(table_locations_aire))]

# %%
table_locations_aire.head()
# Out:
#                          Geo Place Name  Geo Join ID Borough
# 0                   Coney Island (CD13)          313
# 1                                 Bronx            1
# 2      Morris Park and Bronxdale (CD11)          211
# 3  Williamsbridge and Baychester (CD12)          212
# 4                              Brooklyn            2

# %%
table_locations_aire.reset_index(drop= True, inplace=True)

# %%
for i, str in enumerate(table_locations_aire['Geo Place Name'].values):
    for borough, list_district in df_district.values:
        for name in list_district:
            if name.lower() in str.lower():
                table_locations_aire.loc[i, "Borough"] = borough
                print(name, str)
                break
            else:
                print("No district:", name)
# Out:
# No district: Brooklyn
# Coney Island Coney Island (CD13)
# No district: Bronx
# No district: Morris Park
# No district: Williamsbridge
# No district: Belmont
# No district: Kingsbridge
# No district: Northeast Bronx
# No district: Fordham - Bronx Pk
# No district: Pelham
# No district: Crotona
# No district: High Bridge
# No district: Hunts Point
# No district: South Bronk
# No district: Bronx
# No district: Queens
# No district: Long Island City
# No district: Flushing
# No district: Bayside
# No district: Ridgewood
# No district: Fresh Meadows
# No district: Southwest Queens
# No district: Jamaica
# No district: Southeast Queens
# No district: Rockaways
# No district: Staten Island
# No district: Port Richmond
# No district: Stapleton
# No district: Willowbrook
# No district: South Beach
# No district: Northern SI
# No district: Southern SI
# No district: Manhattan
# No district: Financial District
# No district: Greenwich Village
# No district: Lower East Side
# ...

# %%
table_locations_aire["Borough"][table_locations_aire['Borough'] == ""] = "Others Boroughs"

# %%
table_locations_aire
# Out:
#                            Geo Place Name  Geo Join ID        Borough
# 0                     Coney Island (CD13)          313       Brooklyn
# 1                                   Bronx            1          Bronx
# 2        Morris Park and Bronxdale (CD11)          211          Bronx
# 3    Williamsbridge and Baychester (CD12)          212          Bronx
# 4                                Brooklyn            2       Brooklyn
# ..                                    ...          ...            ...
# 109          Union Square-Lower Manhattan       309310      Manhattan
# 110     Bayside Little Neck-Fresh Meadows       404406         Queens
# 111                           Northern SI       501502  Staten Island
# 112                           Southern SI       503504  Staten Island
# 113                           South Bronx    105106107          Bronx
#
# [114 rows x 3 columns]

# %%
df_aire['Borough'] = [np.nan for i in range(len(df_aire))]

# %%
for str, bor in zip(table_locations_aire['Geo Place Name'].values, table_locations_aire['Borough'].values):
    df_aire['Borough'][df_aire['Geo Place Name'] == str] = bor

# %%
df_aire
# Out:
#        Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0         216498           386            Ozone (O3)    Mean          ppb
# 1         216499           386            Ozone (O3)    Mean          ppb
# 2         219969           386            Ozone (O3)    Mean          ppb
# 3         219970           386            Ozone (O3)    Mean          ppb
# 4         164876           383  Sulfur Dioxide (SO2)    Mean          ppb
# ...          ...           ...                   ...     ...          ...
# 16117     671118           386            Ozone (O3)    Mean          ppb
# 16118     671119           386            Ozone (O3)    Mean          ppb
# 16119     671120           386            Ozone (O3)    Mean          ppb
# 16120     671121           386            Ozone (O3)    Mean          ppb
# 16121     671122           386            Ozone (O3)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                          Geo Place Name  \
# ...

# %%
df_aire.to_csv("./modelo ER/Air_Quality.csv", index= False)
